# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
# SAT 2017 contains average scores for SAT examinations aggregated by states in USA. It shows the average scores for Evidence-Based Reading and Writing and Math aggregated by state.
#
# ACT 2017 contains the average scores for ACT examinations aggregated by states in USA. It shows the aggregated scores for English, Math, Reading, Science, Composite and the average participation by each state.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Yes. There are no obvious missing values.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# The standard deviation is very high for SAT Math and there is a minimum value of 52.
# For SAT:
#
# |Evidence-Based|Reading and Writing|Math|Total|
# |---|---|---|---|
# |count|51.000000|51.000000|51.000000|
# |mean|569.117647|547.627451|1126.098039|
# |std|45.666901|84.909119|92.494812|
# |min|482.000000|52.000000|950.000000|
# |max|644.000000|651.000000|1295.000000|

# %%
sat_2017[['State','Math']].sort_values(by='Math').head()
# Out:
#                    State  Math
# 20              Maryland    52
# 8   District of Columbia   468
# 7               Delaware   492
# 12                 Idaho   493
# 22              Michigan   495

# %% [markdown]
# Upon further investigation by visiting the source [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/), this seems to be a human error thus we will correct the error by fixing the Score of Math of Maryland by changing it to 524

# %% [markdown]
# For ACT:
#
# |English|Math|Reading|Science|
# |---|---|---|---|
# |count|52.000000|52.000000|52.000000|52.000000|
# |mean|20.919231|21.173077|22.001923|21.040385|
# |std|2.332132|1.963602|2.048672|3.151113|
# |min|16.300000|18.000000|18.100000|2.300000|
# |25%|19.000000|19.400000|20.475000|19.900000|
# |50%|20.550000|20.900000|21.700000|21.150000|
# |75%|23.300000|23.100000|24.125000|22.525000|
# |max|25.500000|25.300000|26.000000|24.900000|

# %%
act_2017[['State','Science']].sort_values(by='Science').head()
# Out:
#              State  Science
# 21        Maryland      2.3
# 29          Nevada     18.2
# 25     Mississippi     18.8
# 41  South Carolina     18.9
# 34  North Carolina     19.3

# %% [markdown]
# Upon further investigation by visiting the source [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows), this seems to be a human error thus we will correct the error by fixing the Score for Science of Maryland by changing it to 23.2

# %% [raw]
# x = '''	English	Math	Reading	Science
# count	52.000000	52.000000	52.000000	52.000000
# mean	20.919231	21.173077	22.001923	21.040385
# std	2.332132	1.963602	2.048672	3.151113
# min	16.300000	18.000000	18.100000	2.300000
# 25%	19.000000	19.400000	20.475000	19.900000
# 50%	20.550000	20.900000	21.700000	21.150000
# 75%	23.300000	23.100000	24.125000	22.525000
# max	25.500000	25.300000	26.000000	24.900000'''
#
# print(x.replace("\t","|").replace("\n","|\n|"))

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
sat_2017[sat_2017['State'] == 'Maryland']["Math"]
# Out:
# 20    52
# Name: Math, dtype: int64

# %%
sat_2017.loc[sat_2017['State'] == 'Maryland',"Math"] = 524.0

# %%
sat_2017.loc[sat_2017['State'] == 'Maryland',"Math"]
# Out:
# 20    524.0
# Name: Math, dtype: float64

# %%
# Check ACT science Maryland value
act_2017.loc[act_2017['State'] == 'Maryland',"Science"]
# Out:
# 21    2.3
# Name: Science, dtype: float64

# %%
# Fix ACT science Maryland to 23.2
act_2017.loc[act_2017['State'] == 'Maryland',"Science"] = 23.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing      int64
# Math                                  float64
# Total                                   int64
# dtype: object

# %%
#code
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
#
# The Composite column in ACT_2017 is mapped as a string/object. Upon further investigation on the data, it is found that the last row of contains an invalid value, 20.2x which is not a proper float. By cross-referencing with the [source](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows), it is found that the additional 'x' character is a typo  thus we will fix the dataset by changing its value directly. The actual value is 20.2
#
# The participation column for both ACT and SAT are mapped as a string because of the presence of '%' which is not automatically converted to a numeric datatype.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
sat_2017.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %% [markdown]
# ### Code to replace % with actual percentage values
# `sat_2017['Participation'].map(lambda x: float(x.replace("%","")) *0.01 )`

# %%
sat_2017_fixed = sat_2017.copy()
sat_2017_fixed['Participation'] = sat_2017['Participation'].map(lambda x: float(x.replace("%","")) *0.01 )

# %%
act_2017_fixed = act_2017.copy()

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#Change participation column to numeric values
act_2017_fixed['Participation'] = act_2017['Participation'].map(lambda x: float(x.replace("%","")) *0.01 ).astype(float)

# Fix value error at row 51 
#Both does the same thing
act_2017_fixed.loc[51,"Composite"] = float("{0:.2f}".format(20.2))
act_2017_fixed.at[51,"Composite"] = float("{0:.2f}".format(20.2))

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
act_2017_fixed["Composite"] = act_2017_fixed["Composite"].astype(float)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
sat_2017_fixed.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                  float64
# Total                                   int64
# dtype: object

# %%
act_2017_fixed.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
sat_2017_fixed.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
def replace_columns(df,prefix=''):
    return [ prefix +"_"+col.replace("-"," ").replace(" ","_").lower() if col.lower() != 'state' else 'state' for col in df.columns ]

replace_columns(act_2017,prefix='act_2017')
# Out:
# ['state',
#  'act_2017_participation',
#  'act_2017_english',
#  'act_2017_math',
#  'act_2017_reading',
#  'act_2017_science',
#  'act_2017_composite']

# %%
sat_2017_fixed.columns = replace_columns(sat_2017,prefix='sat_2017')

# %%
sat_2017_fixed.columns
# Out:
# Index(['state', 'sat_2017_participation',
#        'sat_2017_evidence_based_reading_and_writing', 'sat_2017_math',
#        'sat_2017_total'],
#       dtype='object')

# %%
act_2017_fixed.columns = replace_columns(act_2017,prefix='act_2017')

# %%
act_2017_fixed.columns
# Out:
# Index(['state', 'act_2017_participation', 'act_2017_english', 'act_2017_math',
#        'act_2017_reading', 'act_2017_science', 'act_2017_composite'],
#       dtype='object')

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %%
sat_2017_fixed.describe()
# Out:
#        sat_2017_participation  sat_2017_evidence_based_reading_and_writing  \
# count               51.000000                                    51.000000
# mean                 0.398039                                   569.117647
# std                  0.352766                                    45.666901
# min                  0.020000                                   482.000000
# 25%                  0.040000                                   533.500000
# 50%                  0.380000                                   559.000000
# 75%                  0.660000                                   613.000000
# max                  1.000000                                   644.000000
#
#        sat_2017_math  sat_2017_total
# count      51.000000       51.000000
# mean      556.882353     1126.098039
# std        47.121395       92.494812
# min       468.000000      950.000000
# 25%       523.500000     1055.500000
# 50%       548.000000     1107.000000
# ...

# %%
act_states = list(act_2017_fixed['state'])
sat_states = list(sat_2017_fixed['state'])

for act_state in act_states:
    if act_state not in sat_states:
        print("Extra row: {}".format(act_state))
# Out:
# Extra row: National

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#National row in act_state can be removed. Run this cell only once!!
act_2017_fixed.drop(0,inplace=True)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_2017 = pd.merge(sat_2017_fixed,act_2017_fixed,left_on='state',right_on='state')

# %%
combined_2017.dtypes
# Out:
# state                                           object
# sat_2017_participation                         float64
# sat_2017_evidence_based_reading_and_writing      int64
# sat_2017_math                                  float64
# sat_2017_total                                   int64
# act_2017_participation                         float64
# act_2017_english                               float64
# act_2017_math                                  float64
# act_2017_reading                               float64
# act_2017_science                               float64
# act_2017_composite                             float64
# dtype: object

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
combined_2017.to_csv('combined_2017.csv', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_excel('../data/act_2018_new.xlsx')

# %%
act_2018_updated = pd.read_csv('../data/act_2018_updated.csv')

# %%
act_2018.head(2)
# Out:
#      State  Participation  English  Math  Reading  Science  Composite
# 0  Alabama            100     18.9  18.3     19.6     19.0       19.1
# 1   Alaska             33     19.8  20.6     21.6     20.7       20.8

# %%
act_2018_updated.head(2)
# Out:
#      State  Percentage of Students Tested  Average Composite Score  \
# 0  Alabama                            100                     19.1
# 1   Alaska                             33                     20.8
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
#
#    Average Science Score
# 0                   19.0
# 1                   20.7

# %%
act_2018.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
# Fix the participation column
act_2018_fixed = act_2018.copy()
act_2018_fixed['Participation'] = act_2018['Participation'].map(lambda x: float(x *0.01 )).astype(float)

act_2018_fixed.columns = replace_columns(act_2018,prefix='act_2018')

# %%
sat_2018_fixed = sat_2018.copy()
sat_2018_fixed['Participation'] = sat_2018['Participation'].map(lambda x: float(x.replace("%","")) *0.01 ).astype(float)

sat_2018_fixed.columns = replace_columns(sat_2018,prefix='sat_2018')

# %%
act_2018_fixed.dtypes
# Out:
# state                      object
# act_2018_participation    float64
# act_2018_english          float64
# act_2018_math             float64
# act_2018_reading          float64
# act_2018_science          float64
# act_2018_composite        float64
# dtype: object

# %%
sat_2018_fixed.dtypes
# Out:
# state                                           object
# sat_2018_participation                         float64
# sat_2018_evidence_based_reading_and_writing      int64
# sat_2018_math                                    int64
# sat_2018_total                                   int64
# dtype: object

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = pd.merge(combined_2017,sat_2018_fixed,on='state')
final = pd.merge(final, act_2018_fixed, on='state')

# %%
final.dtypes
# Out:
# state                                           object
# sat_2017_participation                         float64
# sat_2017_evidence_based_reading_and_writing      int64
# sat_2017_math                                  float64
# sat_2017_total                                   int64
# act_2017_participation                         float64
# act_2017_english                               float64
# act_2017_math                                  float64
# act_2017_reading                               float64
# act_2017_science                               float64
# act_2017_composite                             float64
# sat_2018_participation                         float64
# sat_2018_evidence_based_reading_and_writing      int64
# sat_2018_math                                    int64
# sat_2018_total                                   int64
# act_2018_participation                         float64
# act_2018_english                               float64
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
final.describe().T
# Out:
#                                              count         mean        std  \
# sat_2017_participation                        51.0     0.398039   0.352766
# sat_2017_evidence_based_reading_and_writing   51.0   569.117647  45.666901
# sat_2017_math                                 51.0   556.882353  47.121395
# sat_2017_total                                51.0  1126.098039  92.494812
# act_2017_participation                        51.0     0.652549   0.321408
# act_2017_english                              51.0    20.931373   2.353677
# act_2017_math                                 51.0    21.182353   1.981989
# act_2017_reading                              51.0    22.013725   2.067271
# act_2017_science                              51.0    21.450980   1.739353
# act_2017_composite                            51.0    21.519608   2.020695
# sat_2018_participation                        51.0     0.457451   0.373143
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
eg=[ 1, 3, 4, 5,3,2]
def std(x):
    #1. obtain mean of input
    xmean = np.mean(x)
    return np.sqrt(np.sum([ np.square(elem-xmean) for elem in x ]) / len(x))
std(eg)
# Out:
# 1.2909944487358056

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
final_filtered = final.loc[:,'sat_2017_participation':'act_2018_composite']

# %%
sd = { col : std(values) for col,values in final_filtered.items() }
sd
# Out:
# {'sat_2017_participation': 0.3492907076664507,
#  'sat_2017_evidence_based_reading_and_writing': 45.21697020437866,
#  'sat_2017_math': 46.65713364485504,
#  'sat_2017_total': 91.58351056778743,
#  'act_2017_participation': 0.31824175751231804,
#  'act_2017_english': 2.3304876369363368,
#  'act_2017_math': 1.9624620273436781,
#  'act_2017_reading': 2.046902931484265,
#  'act_2017_science': 1.7222161451443672,
#  'act_2017_composite': 2.0007860815819893,
#  'sat_2018_participation': 0.3694661922353941,
#  'sat_2018_evidence_based_reading_and_writing': 47.03460978357609,
#  'sat_2018_math': 47.301945503783536,
#  'sat_2018_total': 93.22742384464432,
#  'act_2018_participation': 0.3374519488199751,
#  'act_2018_english': 2.4222536143202795,
#  'act_2018_math': 2.0157072555557174,
#  'act_2018_reading': 2.1458918845104216,
#  'act_2018_science': 1.8516885484833538,
#  'act_2018_composite': 2.0855261815801143}

# %%
final.describe().T
# Out:
#                                              count         mean        std  \
# sat_2017_participation                        51.0     0.398039   0.352766
# sat_2017_evidence_based_reading_and_writing   51.0   569.117647  45.666901
# sat_2017_math                                 51.0   556.882353  47.121395
# sat_2017_total                                51.0  1126.098039  92.494812
# act_2017_participation                        51.0     0.652549   0.321408
# act_2017_english                              51.0    20.931373   2.353677
# act_2017_math                                 51.0    21.182353   1.981989
# act_2017_reading                              51.0    22.013725   2.067271
# act_2017_science                              51.0    21.450980   1.739353
# act_2017_composite                            51.0    21.519608   2.020695
# sat_2018_participation                        51.0     0.457451   0.373143
# ...

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer
#
# The standard deviation calculated by using our own std function or numpy's std function differs from the output from pandas. The reason is that pandas describe() function uses sample means standard deviation calculation while numpy.std() uses population standard deviation calculation

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - [Which states have the highest and lowest mean total/composite scores for the:](#Total-/-Composite-Scores--Analysis)
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - [Do any states with 100% participation on a given test have a rate change year-to-year?](#Do-any-states-with-100%-participation-on-a-given-test-have-a-rate-change-year-to-year?)
# - [Do any states show have >50% participation on *both* tests either year?](#States-with->-50%-participations-on-both-test-for-year-2017)
#
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
def sort_df(df,col='', asc=True, size=5):
    return df.loc[:,["state",col]].sort_values(by=[col],ascending=asc).head(size)

# %% [markdown]
# ## Participation Rates Analysis
# - SAT
#     - 2017
#         - [Highest Participation Rates by State](#SAT-2017-Highest-Participation-Rates-by-State)
#         - [Lowest Participation Rates by State](#SAT-2017-Lowest-participation-Rates-by-State)
#     - 2018
#         - [Highest Participation Rates by State](#SAT-2018-Highest-Participation-Rates-by-State)
#         - [Lowest Participation Rates by State](#SAT-2018-Lowest-Participation-Rates-by-State)
# - ACT
#     - 2017
#         - [Highest Participation Rates by State](#ACT-2017-Highest-Participation-Rates-by-State)
#         - [Lowest Participation Rates by State](#ACT-2017-Lowest-Participation-Rates-by-State)
#     - 2018
#         - [Highest Participation Rates by State](#ACT-2018-Highest-Participation-Rates-by-State)
#         - [Lowest Participation Rates by State](#ACT-2018-Lowest-Participation-Rates-by-State)

# %%
def title_to_link(x):
    return x.replace(" ","-")

# %%
x = 'Total / Composite Scores  Analysis'
title_to_link(x)
# Out:
# 'Total-/-Composite-Scores--Analysis'

# %%
p_cols = ['sat_2017_participation', 'sat_2018_participation', 'act_2017_participation', 'act_2018_participation' ]
p_inputs = [ [col, asc ]  for col in p_cols for asc in [False, True]]
p_inputs
# Out:
# [['sat_2017_participation', False],
#  ['sat_2017_participation', True],
#  ['sat_2018_participation', False],
#  ['sat_2018_participation', True],
#  ['act_2017_participation', False],
#  ['act_2017_participation', True],
#  ['act_2018_participation', False],
#  ['act_2018_participation', True]]

# %%
result_set = [ sort_df(final, col=inp[0], asc=inp[1]) for inp in p_inputs ]

# %% [markdown]
# ### SAT 2017 Highest Participation Rates by State

# %%
result_set[0]
# Out:
#                    state  sat_2017_participation
# 8   District of Columbia                    1.00
# 22              Michigan                    1.00
# 6            Connecticut                    1.00
# 7               Delaware                    1.00
# 29         New Hampshire                    0.96

# %% [markdown]
# ### SAT 2017 Lowest participation Rates by State

# %%
result_set[1]
# Out:
#            state  sat_2017_participation
# 34  North Dakota                    0.02
# 24   Mississippi                    0.02
# 15          Iowa                    0.02
# 25      Missouri                    0.03
# 44          Utah                    0.03

# %% [markdown]
# ### SAT 2018 Highest Participation Rates by State

# %%
result_set[2]
# Out:
#           state  sat_2018_participation
# 5      Colorado                     1.0
# 6   Connecticut                     1.0
# 7      Delaware                     1.0
# 22     Michigan                     1.0
# 12        Idaho                     1.0

# %% [markdown]
# ### SAT 2018 Lowest Participation Rates by State

# %%
result_set[3]
# Out:
#            state  sat_2018_participation
# 34  North Dakota                    0.02
# 50       Wyoming                    0.03
# 41  South Dakota                    0.03
# 27      Nebraska                    0.03
# 49     Wisconsin                    0.03

# %% [markdown]
# ### ACT 2017 Highest Participation Rates by State

# %%
result_set[4]
# Out:
#         state  act_2017_participation
# 0     Alabama                     1.0
# 17   Kentucky                     1.0
# 49  Wisconsin                     1.0
# 44       Utah                     1.0
# 42  Tennessee                     1.0

# %% [markdown]
# ### ACT 2017 Lowest Participation Rates by State

# %%
result_set[5]
# Out:
#             state  act_2017_participation
# 19          Maine                    0.08
# 29  New Hampshire                    0.18
# 7        Delaware                    0.18
# 39   Rhode Island                    0.21
# 38   Pennsylvania                    0.23

# %% [markdown]
# ### ACT 2018 Highest Participation Rates by State

# %%
result_set[6]
# Out:
#         state  act_2018_participation
# 0     Alabama                     1.0
# 17   Kentucky                     1.0
# 49  Wisconsin                     1.0
# 44       Utah                     1.0
# 42  Tennessee                     1.0

# %% [markdown]
# ### ACT 2018 Lowest Participation Rates by State

# %%
result_set[7]
# Out:
#             state  act_2018_participation
# 19          Maine                    0.07
# 39   Rhode Island                    0.15
# 29  New Hampshire                    0.16
# 7        Delaware                    0.17
# 38   Pennsylvania                    0.20

# %% [markdown]
# ***
# ### Total / Composite Scores  Analysis
# - SAT
#     - 2017
#         - [Highest Total Score by State](#SAT-2017-Highest-Total-Score-by-State)
#         - [Lowest Total Score by State](#SAT-2017-Lowest-Total-Score-by-State)
#     - 2018
#         - [Highest Total Score by State](#SAT-2018-Highest-Total-Score-by-State)
#         - [Lowest Total Score by State](#SAT-2018-Lowest-Total-Score-by-State)
# - ACT
#     - 2017
#         - [Highest Composite Score by State](#ACT-2017-Highest-Composite-Score-by-State)
#         - [Lowest Composite Score by State](#ACT-2017-Lowest-Composite-Score-by-State)
#     - 2018
#         - [Highest Composite Score by State](#ACT-2018-Highest-Composite-Score-by-State)
#         - [Lowest Composite Score by State](#ACT-2018-Lowest-Composite-Score-by-State)

# %%
t_cols = ['sat_2017_total', 'sat_2018_total', 'act_2017_composite', 'act_2018_composite' ]
t_inputs = [ [col, asc ]  for col in t_cols for asc in [False, True]]
t_inputs
# Out:
# [['sat_2017_total', False],
#  ['sat_2017_total', True],
#  ['sat_2018_total', False],
#  ['sat_2018_total', True],
#  ['act_2017_composite', False],
#  ['act_2017_composite', True],
#  ['act_2018_composite', False],
#  ['act_2018_composite', True]]

# %%
t_results =  [ sort_df(final, col=inp[0], asc=inp[1]) for inp in t_inputs ]

# %% [markdown]
# ### SAT 2017 Highest Total Score by State

# %%
t_results[0]
# Out:
#         state  sat_2017_total
# 23  Minnesota            1295
# 49  Wisconsin            1291
# 15       Iowa            1275
# 25   Missouri            1271
# 16     Kansas            1260

# %% [markdown]
# ### SAT 2017 Lowest Total Score by State

# %%
t_results[1]
# Out:
#                    state  sat_2017_total
# 8   District of Columbia             950
# 7               Delaware             996
# 12                 Idaho            1005
# 22              Michigan            1005
# 19                 Maine            1012

# %% [markdown]
# ### SAT 2018 Highest Total Score by State

# %%
t_results[2]
# Out:
#            state  sat_2018_total
# 23     Minnesota            1298
# 49     Wisconsin            1294
# 34  North Dakota            1283
# 15          Iowa            1265
# 16        Kansas            1265

# %% [markdown]
# ### SAT 2018 Lowest Total Score by State

# %%
t_results[3]
# Out:
#                    state  sat_2018_total
# 8   District of Columbia             977
# 7               Delaware             998
# 48         West Virginia             999
# 12                 Idaho            1001
# 44                  Utah            1010

# %% [markdown]
# ### ACT 2017 Highest Composite Score by State

# %%
t_results[4]
# Out:
#                    state  act_2017_composite
# 29         New Hampshire                25.5
# 21         Massachusetts                25.4
# 6            Connecticut                25.2
# 19                 Maine                24.3
# 8   District of Columbia                24.2

# %% [markdown]
# ### ACT 2017 Lowest Composite Score by State

# %%
t_results[5]
# Out:
#              state  act_2017_composite
# 28          Nevada                17.8
# 24     Mississippi                18.6
# 40  South Carolina                18.7
# 11          Hawaii                19.0
# 33  North Carolina                19.1

# %% [markdown]
# ### ACT 2018 Highest Composite Score by State

# %%
t_results[6]
# Out:
#             state  act_2018_composite
# 6     Connecticut                25.6
# 21  Massachusetts                25.5
# 29  New Hampshire                25.1
# 32       New York                24.5
# 22       Michigan                24.4

# %% [markdown]
# ### ACT 2018 Lowest Composite Score by State

# %%
t_results[7]
# Out:
#              state  act_2018_composite
# 28          Nevada                17.7
# 40  South Carolina                18.3
# 24     Mississippi                18.6
# 11          Hawaii                18.9
# 0          Alabama                19.1

# %% [markdown]
# #### Do any states with 100% participation on a given test have a rate change year-to-year?

# %% [markdown]
# ### For SAT

# %%
sat_rc = final[(final[['sat_2017_participation','sat_2018_participation']] == 1.0).any(axis=1)][['state','sat_2017_participation','sat_2018_participation']]
sat_rc
# Out:
#                    state  sat_2017_participation  sat_2018_participation
# 5               Colorado                    0.11                    1.00
# 6            Connecticut                    1.00                    1.00
# 7               Delaware                    1.00                    1.00
# 8   District of Columbia                    1.00                    0.92
# 12                 Idaho                    0.93                    1.00
# 22              Michigan                    1.00                    1.00

# %% [markdown]
# ### SAT Rate changes for states with 100% participation
# - Colorado had a participation rate of 11% at 2017 and a 100% participation rate at 2018
# - District of Columbia had a participation rate of 100% at 2017 and 92% at 2018
# - Idaho had a participation rate of 93% at 2017 and 100% at 2018

# %%
act_rc = final[(final[['act_2017_participation','act_2018_participation']] == 1.0).any(axis=1)][['state','act_2017_participation','act_2018_participation']]
act_rc[act_rc['act_2017_participation'] != act_rc['act_2018_participation']]
# Out:
#         state  act_2017_participation  act_2018_participation
# 5    Colorado                    1.00                    0.30
# 23  Minnesota                    1.00                    0.99
# 27   Nebraska                    0.84                    1.00
# 35       Ohio                    0.75                    1.00

# %% [markdown]
# ### ACT Rate changes for states with 100% participations
# - Colorado had 100% participation at 2017 and 30% at 2018
# - Minnesota had 100% participation at 2017 and 99% at 2018
# - Nebraska had 84% at 2017 and 100% at 2018
# - Ohio had 75% participation at 2017 and 100% at 2018

# %% [markdown]
# #### Observations
# For Colorado, the data suggest that the majority of students have shifted from taking ACT at 2017 to taking SAT at 2018, as the SAT participation rate have increased significatly
# ***

# %% [markdown]
# ### Do any states show have >50% participation on both tests either year?

# %%
final[(final['sat_2017_participation'] > 0.5) & ( final['act_2017_participation'] > 0.5)][['state','sat_2017_participation','act_2017_participation']]
# Out:
#       state  sat_2017_participation  act_2017_participation
# 9   Florida                    0.83                    0.73
# 10  Georgia                    0.61                    0.55
# 11   Hawaii                    0.55                    0.90

# %% [markdown]
# #### States with > 50% participations on both test for year 2017
# Florida, Georgia and Hawaii have participation rates above 50% in 2017 for both ACT and SAT

# %%
final[(final['sat_2018_participation'] > 0.5) & ( final['act_2018_participation'] > 0.5)][['state','sat_2018_participation','act_2018_participation']]
# Out:
#              state  sat_2018_participation  act_2018_participation
# 9          Florida                    0.56                    0.66
# 10         Georgia                    0.70                    0.53
# 11          Hawaii                    0.56                    0.89
# 33  North Carolina                    0.52                    1.00
# 40  South Carolina                    0.55                    1.00

# %% [markdown]
# #### States with > 50% participations on both test for year 2018
# Florida, Georgia, Hawaii, North Carolina and South Carolina have participation rates above 50% in 2018 for both ACT and SAT
# It suggests that the students from these states are not too biased towards either one of each test, and that both tests may be equally recognized and accepted by most of the colleges and universities in that area.
# ***

# %% [markdown]
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.

# %% [markdown]
# - Particiation rates in Florida in both SAT and ACT have reduced in 2018, compared to 2017 for some reason.
# - For ACT , Colodaro had a participation rate of 100% at 2017 but it reduced drastically to 30% at 2018, which is interesting.
#
# ***

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(10,10))
sns.heatmap(final.corr()).set_title("SAT & ACT 2017 & 2018 Heatmap ")
# Out:
# Text(0.5, 1, 'SAT & ACT 2017 & 2018 Heatmap ')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels,figsize=(6,6),sharex=True,sharey=True):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=figsize,sharex=sharex, sharey=sharey) # You'll want to specify your figsize
    
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_title("Distrib. of " + list_of_titles[i].replace("_"," ").title())
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel("Freq.")
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# ## Plot and interpret histograms
# For each of the following:
# - [Participation rates for SAT & ACT](#Participation-rates-for-SAT-&-ACT)
# - [Math scores for SAT & ACT](#Math-scores-for-SAT-&-ACT)
# - [Reading/verbal scores for SAT & ACT](#Reading/verbal-scores-for-SAT-&-ACT)

# %% [markdown]
# ### Participation rates for SAT & ACT

# %%
# Code
cols=['sat_2017_participation','sat_2018_participation','act_2017_participation','act_2018_participation']
xlabels = [ "Participation Rate" for _ in range(len(cols))]
subplot_histograms(final, cols, cols, xlabels,figsize=(15,15))

# %% [markdown]
# ## Participation Rate comparision
# - ### 2017 vs 2018
#     - [SAT 2017 vs SAT 2018](#SAT-2017-vs-SAT-2018)
#     - [ACT 2017 vs ACT 2018](#ACT-2017-vs-ACT-2018)
#
# - ### SAT vs ACT
#     - [SAT 2017 vs ACT 2017](#SAT-2017-vs-ACT-2017)
#     - [SAT 2018 vs ACT 2018](#SAT-2018-vs-ACT-2018)

# %% [markdown]
# ### 2017 vs 2018

# %% [markdown]
# ### SAT 2017 vs SAT 2018
# The participation rates for SAT 2017 and 2018 is quite similar with some of the following observations:
#     1. The number of zero participations in 2018 appears to be slightly lower compared to 2017.
#     2. Overall, the participation in 2018 is higher than 2017, as shown by the following details:
#          > Median of participation in 2018(0.52) is higher than 2017(0.38).
#          > Mean of participation in 2018(0.45) is higher than 2017(0.39).

# %%
final[['sat_2017_participation','sat_2018_participation']].describe()
# Out:
#        sat_2017_participation  sat_2018_participation
# count               51.000000               51.000000
# mean                 0.398039                0.457451
# std                  0.352766                0.373143
# min                  0.020000                0.020000
# 25%                  0.040000                0.045000
# 50%                  0.380000                0.520000
# 75%                  0.660000                0.775000
# max                  1.000000                1.000000

# %% [markdown]
# ### ACT 2017 vs ACT 2018
# In overall, participation rate for ACT 2018 is lower that ACT 2017:
#     1. The number of zero participations in 2018 appears to be slightly higher compared to 2017.
#     2. Median of participation in 2018(0.66) is lower than 2017(0.69).
#     3. Mean of participation in 2018(0.62) is lower than 2017(0.65).

# %%
final[['act_2017_participation','act_2018_participation']].describe()
# Out:
#        act_2017_participation  act_2018_participation
# count               51.000000               51.000000
# mean                 0.652549                0.616471
# std                  0.321408                0.340810
# min                  0.080000                0.070000
# 25%                  0.310000                0.285000
# 50%                  0.690000                0.660000
# 75%                  1.000000                1.000000
# max                  1.000000                1.000000

# %% [markdown]
# ### SAT 2017 vs ACT 2017
#
# In overall, ACT has a higher participation rate compared to SAT in 2017.
#     1. Median of ACT(0.69) is higher than SAT(0.38)
#     2. Mean of ACT(0.65) is higher than SAT(0.39)

# %%
final[['sat_2017_participation','act_2017_participation']].describe()
# Out:
#        sat_2017_participation  act_2017_participation
# count               51.000000               51.000000
# mean                 0.398039                0.652549
# std                  0.352766                0.321408
# min                  0.020000                0.080000
# 25%                  0.040000                0.310000
# 50%                  0.380000                0.690000
# 75%                  0.660000                1.000000
# max                  1.000000                1.000000

# %% [markdown]
# ### SAT 2018 vs ACT 2018

# %% [markdown]
# In overall, ACT has a higher participation rate compared to SAT in 2017.
#
# 1. Median of ACT(0.66) is higher than SAT(0.52)
# 2. Mean of ACT(0.61) is higher than SAT(0.45)

# %%
final[['sat_2018_participation','act_2018_participation']].describe()
# Out:
#        sat_2018_participation  act_2018_participation
# count               51.000000               51.000000
# mean                 0.457451                0.616471
# std                  0.373143                0.340810
# min                  0.020000                0.070000
# 25%                  0.045000                0.285000
# 50%                  0.520000                0.660000
# 75%                  0.775000                1.000000
# max                  1.000000                1.000000

# %% [markdown]
# ****

# %% [markdown]
# ### Math scores for SAT & ACT
# - [SAT-2017-Math-vs-SAT-2018-Math](#SAT-2017-Math-vs-SAT-2018-Math)
# - [ACT 2017 Math vs ACT 2018 Math](#ACT-2017-Math-vs-ACT-2018-Math)

# %% [markdown]
# #### SAT 2017 Math vs SAT 2018 Math

# %%
cols=['sat_2017_math','sat_2018_math']
xlabels = [ "Score" for _ in range(len(cols))]
subplot_histograms(final, cols, cols, xlabels,figsize=(15,6))

# %% [markdown]
# #### ACT 2017 Math vs ACT 2018 Math

# %%
cols=['act_2017_math','act_2018_math']
xlabels = [ "Score" for _ in range(len(cols))]
subplot_histograms(final, cols, cols, xlabels,figsize=(15,6))

# %% [markdown]
# ### Reading/verbal scores for SAT & ACT
# - SAT
#     - [SAT 2017 VS SAT 2018 Reading/Verbal Scores](#SAT-2017-VS-SAT-2018-Reading/Verbal-Scores)
# - ACT
#     - [ACT 2017 vs ACT 2018 Reading/Verbal Scores](#ACT-2017-VS-SAT-2018-Reading/Verbal-Scores)

# %%
cols=['sat_2017_evidence_based_reading_and_writing','sat_2018_evidence_based_reading_and_writing']
xlabels = [ "Score" for _ in range(len(cols))]
subplot_histograms(final, cols, cols, xlabels,figsize=(15,6))

# %%
final[['sat_2017_evidence_based_reading_and_writing','sat_2018_evidence_based_reading_and_writing']].describe()
# Out:
#        sat_2017_evidence_based_reading_and_writing  \
# count                                    51.000000
# mean                                    569.117647
# std                                      45.666901
# min                                     482.000000
# 25%                                     533.500000
# 50%                                     559.000000
# 75%                                     613.000000
# max                                     644.000000
#
#        sat_2018_evidence_based_reading_and_writing
# count                                    51.000000
# mean                                    563.686275
# std                                      47.502627
# min                                     480.000000
# 25%                                     534.500000
# 50%                                     552.000000
# 75%                                     610.500000
# max                                     643.000000

# %% [markdown]
# #### SAT 2017 VS SAT 2018 Reading/Verbal Scores
# The distribution of SAT 2017 vs SAT 2018 Reading/Verbal scores do not deviate much in between with very similar means and medians each.

# %% [markdown]
# #### ACT 2017 vs ACT 2018 Reading/Verbal Scores

# %%
cols=['act_2017_reading','act_2018_reading']
xlabels = [ "Score" for _ in range(len(cols))]
subplot_histograms(final, cols, cols, xlabels,figsize=(15,6))

# %%
final[['act_2017_reading','act_2018_reading']].describe()
# Out:
#        act_2017_reading  act_2018_reading
# count         51.000000         51.000000
# mean          22.013725         22.015686
# std            2.067271          2.167245
# min           18.100000         18.000000
# 25%           20.450000         20.450000
# 50%           21.800000         21.600000
# 75%           24.150000         24.100000
# max           26.000000         26.100000

# %% [markdown]
# The distribution of ACT 2017 vs ACT 2018 Reading scores do not deviate much in between with very similar means and medians each.
# ***

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - [SAT vs. ACT math scores for 2017](#SAT-vs-ACT-math-scores-for-2017)
# - [SAT vs. ACT verbal/reading scores for 2017](#SAT-vs.-ACT-verbal/reading-scores-for-2017)
# - [SAT vs. ACT total/composite scores for 2017](#SAT-vs.-ACT-total/composite-scores-for-2017)
# - [Total scores for SAT 2017 vs. 2018](#Total-scores-for-SAT-2017-vs.-2018)
# - [Composite scores for ACT 2017 vs. 2018](#Composite-scores-for-ACT-2017-vs.-2018)
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# ### SAT vs ACT math scores for 2017

# %%
cols = ['sat_2017_math','act_2017_math']
xlabels = ['Scores']*len(cols)
sat_vs_math_2017 = final[cols]

# %%
sat_vs_math_2017.head()
# Out:
#    sat_2017_math  act_2017_math
# 0          572.0           18.4
# 1          533.0           19.8
# 2          553.0           19.8
# 3          594.0           19.0
# 4          524.0           22.7

# %%
def getScatter(cols,title=None):
    if not title:
        title = " vs ".join([col.replace("_"," ").title() for col in cols])
    ax = sns.lmplot(data=final[cols], x=cols[1],y=cols[0])
    plt.title(title)
    plt.xlabel(cols[1].replace("_"," ").title())
    plt.ylabel(cols[0].replace("_"," ").title())

# %%
cols=['sat_2017_math','act_2017_math']
getScatter(cols)

# %% [markdown]
# From the scatterplot, it appears that there are no visible correlations between ACT and SAT math scores

# %% [markdown]
# ### SAT vs. ACT verbal/reading scores for 2017

# %%
cols = ['sat_2017_evidence_based_reading_and_writing','act_2017_reading']
getScatter(cols)

# %% [markdown]
# #### From the scatterplot, it appears that there are no visible correlations between ACT and SAT verbal/reading scores for 2017

# %% [markdown]
# ### SAT vs. ACT total/composite scores for 2017

# %%
cols = ['sat_2017_total','act_2017_composite']
getScatter(cols)

# %% [markdown]
# From the scatterplot, it appears that there are no visible correlations between ACT and SAT total/composite scores for 2017

# %% [markdown]
# ### Total scores for SAT 2017 vs. 2018

# %%
cols = ['sat_2017_total','sat_2018_total']
getScatter(cols)

# %% [markdown]
# #### From the scatterplot, it appears that there is a strong correlation betwen the SAT scores for 2017 vs SAT scores for 2018
# This observation means that states that have a history of good SAT scores are likely to perform well on the subsequent years as well, vice versa for states that have performed poorly

# %% [markdown]
# ### Composite scores for ACT 2017 vs. 2018

# %%
cols = ['act_2017_composite','act_2018_composite']
getScatter(cols)

# %% [markdown]
# #### From the scatterplot, it appears that there is a strong correlation betwen the ACT scores for 2017 vs ACT scores for 2018
# This observation means that states that have a history of good ACT scores are likely to perform well on the subsequent years as well, vice versa for states that have performed poorly
#
# ***

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# ### Seaborn Plots:
# 1. Participation
#     - sat_2017_participation
#     - sat_2018_participation
#     - act_2017_participation
#     - act_2018_participation
#
# 2. SAT Math & Reading and writing
#     - sat_2017_evidence_based_reading_and_writing
#     - sat_2017_math
#     - sat_2018_evidence_based_reading_and_writing
#     - sat_2018_math
#
# 3. SAT Total
#     - sat_2017_total
#     - sat_2018_total
#
# 4. ACT Scores for English, Math, Reading, Science, Composite
#     - act_2017_english
#     - act_2017_math
#     - act_2017_reading
#     - act_2017_science
#     - act_2017_composite
#     - act_2018_english
#     - act_2018_math
#     - act_2018_reading
#     - act_2018_science
#     - act_2018_composite

# %% [markdown]
# ### Participation Rate comparision

# %%
# Participation Rate plot
partcip_cols = ['sat_2017_participation','sat_2018_participation','act_2017_participation','act_2018_participation']
particip_df = final[partcip_cols]

plt.figure(figsize=(16,5))
plt.title('Participation Rate comparison')
plt.ylabel("Participation Rate")
sns.boxplot(data=particip_df);

# %% [markdown]
# ### From the boxplot, we could compare between:
# #### SAT 2017 vs SAT 2018
#     - SAT 2018 has a higher participation rate compared to 2017. The median for 2018 is visibly higher than 2017. The third quartile for 2018 is also higher than 2017
# #### ACT 2017 vs ACT 2018
#     - ACT 2017 has a visibly higher median for participation compared to 2018. It means that participation rates for ACT 2018 and is slightly lower compared to 2017.
#
# #### SAT VS ACT
#     - ACT in general have a higher participation rate compared to SAT for both years

# %%
# Sat reading and writing and math scores

# Participation Rate plot
sns_cols = ['sat_2017_evidence_based_reading_and_writing','sat_2018_evidence_based_reading_and_writing','sat_2017_math','sat_2018_math']
sns_df = final[sns_cols]

plt.figure(figsize=(16,5))
plt.title('SAT Reading & Writing and Math Scores')
plt.ylabel("Scores")
plt.xlabel("Categories")
sns.boxplot(data=sns_df);

# %% [markdown]
# ### 2017 vs 2018
#     - Reading & Writing
#         - SAT 2018 R&W scores are slightly lower compared to 2017, it has a visibly lower median.
#     - Math
#         - SAT 2018 Math scores are slightly lower compared to 2017, it has a visibly lower median.
#     Reading & Writing Vs Math
#         - In general Math scores have a slightly lower median compared to Reading & Writing median scores.

# %% [markdown]
# ### SAT Total Scores Comparison between 2017 vs 2018

# %%
sns_cols = ['sat_2017_total','sat_2018_total']
sns_df = final[sns_cols]

plt.figure(figsize=(16,5))
plt.title('2017 vs 2018 SAT total Scores')
plt.ylabel("Scores")
sns.boxplot(data=sns_df);

# %% [markdown]
# #### The median SAT score for 2018 is lower compared to the median score for 2017

# %% [markdown]
# ### ACT Scores for English, Math, Reading, Science, Composite

# %%
sns_cols = ['act_2017_english','act_2017_math','act_2017_reading','act_2017_science','act_2017_composite','act_2018_english',
           'act_2018_math','act_2018_reading','act_2018_science','act_2018_composite']
sns_df = final[sns_cols]

plt.figure(figsize=(16,5))
plt.title('ACT Scores Comparison')
plt.ylabel("Scores")
sns.boxplot(data=sns_df);

# %% [markdown]
# #### ACT Scores comparison by subject
# The box plot above segregates ACT scores into two major groups by year, 2017 and 2018.
# - Within 2017, the subjects with top ACT scores based on median are Reading, science, math and english. (Composite is not a good metric to be measure here)
# - Within 2018, the top subjects based on median of scores are again Reading, science, math and english, which is similar to 2017.

# %%
sns_cols = ['act_2017_english','act_2018_english','act_2017_math','act_2018_math','act_2017_reading','act_2018_reading',
            'act_2017_science','act_2018_science','act_2017_composite','act_2018_composite']
sns_df = final[sns_cols]

plt.figure(figsize=(16,5))
plt.title('ACT Scores Comparison')
plt.ylabel("Scores")
sns.boxplot(data=sns_df);

# %% [markdown]
# #### ACT Scores comparison by year
# The box plot above segregates ACT scores by subjects for 2017 and 2018
# - English
#     - Median scores for english have visibly declined in 2018 compared to 2017
# - Math
#     - Median scores for math have declined in 2018 compared to 2017
# - Reading
#     - Median scores for reading have declined in 2018 compared to 2017
# - Science
#     - Median scores for science have declined in 2018 compared to 2017
# - Composite
#     - Median composite score for ACT have declined in 2018 compared to 2017
#
# In average, the ACT scores in 2018 have declined compared to 2017

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
final[(final['sat_2017_participation'] < 0.5) & (final['act_2017_participation'] < 0.5)][['state','sat_2017_participation','sat_2017_total','act_2017_participation','act_2017_composite']]
# Out:
#      state  sat_2017_participation  sat_2017_total  act_2017_participation  \
# 37  Oregon                    0.43            1108                     0.4
#
#     act_2017_composite
# 37                21.8

# %%
final[(final['sat_2018_participation'] < 0.5) & (final['act_2018_participation'] < 0.5)][['state','sat_2018_participation','sat_2018_total','act_2018_participation','act_2018_composite']]
# Out:
#      state  sat_2018_participation  sat_2018_total  act_2018_participation  \
# 1   Alaska                    0.43            1106                    0.33
# 37  Oregon                    0.48            1117                    0.42
#
#     act_2018_composite
# 1                 20.8
# 37                21.3

# %%
avg_participation_2018 = final[['state','sat_2018_participation','act_2018_participation']]
avg_participation_2018.loc[:,'avg_participation'] = avg_participation_2018.mean(axis=1)
# Out:
# C:\Users\User\Anaconda3\envs\dsi\lib\site-packages\pandas\core\indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\User\Anaconda3\envs\dsi\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
avg_participation_2018.sort_values(by=['avg_participation'], ascending=True).head(5)
# Out:
#            state  sat_2018_participation  act_2018_participation  \
# 15          Iowa                    0.03                    0.68
# 16        Kansas                    0.04                    0.71
# 1         Alaska                    0.43                    0.33
# 41  South Dakota                    0.03                    0.77
# 31    New Mexico                    0.16                    0.67
#
#     avg_participation
# 15              0.355
# 16              0.375
# 1               0.380
# 41              0.400
# 31              0.415

# %% [markdown]
# ### States with lowest participation scores in both tests:
#     1. Iowa (Lowest)
#     2. Kansas
#     3. Alaska
#     4. South Dakota
#     5. New Mexico
#
# The 5 states above appears to have the lowest mean participation scores for both ACT and SAT in 2018. Most of the states have a bias towards either one of the test, but Alaska appears to have a low participation rate ( < 0.5) for both tests. This suggest that ACT and SAT tests aren't a heavy focus in Alaska.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %%
sns.pairplot(final[['state', 'act_2017_participation', 'act_2017_english',
       'act_2017_math', 'act_2017_reading', 'act_2017_science',
       'act_2017_composite']]);

# %% [markdown]
# - From the plot, there is a high correlation between subject scores between English, Math, reading, science and composite score.
# - A high participation rate does not necessarily relate to a high composite score

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %%
cols=['sat_2017_evidence_based_reading_and_writing', 'sat_2017_math',
       'sat_2017_total', 'act_2017_english',
       'act_2017_math', 'act_2017_reading', 'act_2017_science',
       'act_2017_composite',
       'sat_2018_evidence_based_reading_and_writing', 'sat_2018_math',
       'sat_2018_total', 'act_2018_english',
       'act_2018_math', 'act_2018_reading', 'act_2018_science',
       'act_2018_composite']
xlabels = [ "Score" for _ in range(len(cols))]
subplot_histograms(final, cols, cols, xlabels,figsize=(16,60), sharex=False, sharey=False)

# %%
cols=['sat_2017_participation','act_2017_participation','sat_2018_participation','act_2018_participation']
xlabels = [ "Participation Rate" for _ in range(len(cols))]
subplot_histograms(final, cols, cols, xlabels,figsize=(16,13), sharex=False, sharey=False)

# %%
final.describe().T
# Out:
#                                              count         mean        std  \
# sat_2017_participation                        51.0     0.398039   0.352766
# sat_2017_evidence_based_reading_and_writing   51.0   569.117647  45.666901
# sat_2017_math                                 51.0   556.882353  47.121395
# sat_2017_total                                51.0  1126.098039  92.494812
# act_2017_participation                        51.0     0.652549   0.321408
# act_2017_english                              51.0    20.931373   2.353677
# act_2017_math                                 51.0    21.182353   1.981989
# act_2017_reading                              51.0    22.013725   2.067271
# act_2017_science                              51.0    21.450980   1.739353
# act_2017_composite                            51.0    21.519608   2.020695
# sat_2018_participation                        51.0     0.457451   0.373143
# ...

# %%
final[['sat_2017_participation','act_2017_participation','sat_2018_participation','act_2018_participation']].describe()
# Out:
#        sat_2017_participation  act_2017_participation  sat_2018_participation  \
# count               51.000000               51.000000               51.000000
# mean                 0.398039                0.652549                0.457451
# std                  0.352766                0.321408                0.373143
# min                  0.020000                0.080000                0.020000
# 25%                  0.040000                0.310000                0.045000
# 50%                  0.380000                0.690000                0.520000
# 75%                  0.660000                1.000000                0.775000
# max                  1.000000                1.000000                1.000000
#
#        act_2018_participation
# count               51.000000
# mean                 0.616471
# std                  0.340810
# min                  0.070000
# 25%                  0.285000
# 50%                  0.660000
# 75%                  1.000000
# ...

# %% [markdown]
# ### Participation Rates distribution
# - By analyzing the distribution graph, participation rates for both SAT and ACT in 2017 and 2018 appears to not follow a normal distribution
# - ACT have a higher mean and median in overall compared to SAT
# - SAT have a larger spread / standard deviation compared to ACT

# %%
from scipy.stats import normaltest

# %%
def isnormal(arr, alpha=0.05):
    s,p = normaltest(a=arr)
    alpha = alpha
    summary = arr.describe()[['mean','std','50%']]
    if p < alpha: # Null hypothesis : arr comes from a normal distribution
        return "{} does not come from a normal distribution, based on a student t test with threshold of {:0.3f} and p value:{:0.3f}. The null hypothesis can be rejected.\
 It has a mean of {:0.3f}, median of {:0.3f} and standard deviation of {:0.3f}" .format(arr.name.replace("_",' ').title(),alpha ,p, summary['mean'],summary['50%'],summary['std'])
    else:
        # Null hypothesis cannot be rejected
        return "***{} comes from a normal distribution***, based on a student t test with threshold of {:0.3f} and p value:{:0.3f}. It has a mean of {:0.3f}, median of {:0.3f} and standard deviation of {:0.3f}" \
    .format(arr.name.replace("_",' ').title(), alpha, p,summary['mean'],summary['50%'],summary['std'])

# %%
results = [ isnormal(final[var],alpha=0.05) for var in final.columns[1:]]

# print("\n- ".join(results))

# %% [markdown]
# ###  Summary
# - Sat 2017 Participation does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.000. The null hypothesis can be rejected. It has a mean of 0.398, median of 0.380 and standard deviation of 0.353
# - Sat 2017 Evidence Based Reading And Writing does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.001. The null hypothesis can be rejected. It has a mean of 569.118, median of 559.000 and standard deviation of 45.667
# - ***Sat 2017 Math comes from a normal distribution***, based on a student t test with threshold of 0.050 and p value:0.056. It has a mean of 556.882, median of 548.000 and standard deviation of 47.121
# - Sat 2017 Total does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.008. The null hypothesis can be rejected. It has a mean of 1126.098, median of 1107.000 and standard deviation of 92.495
# - Act 2017 Participation does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.000. The null hypothesis can be rejected. It has a mean of 0.653, median of 0.690 and standard deviation of 0.321
# - ***Act 2017 English comes from a normal distribution***, based on a student t test with threshold of 0.050 and p value:0.084. It has a mean of 20.931, median of 20.700 and standard deviation of 2.354
# - Act 2017 Math does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.038. The null hypothesis can be rejected. It has a mean of 21.182, median of 20.900 and standard deviation of 1.982
# - Act 2017 Reading does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.044. The null hypothesis can be rejected. It has a mean of 22.014, median of 21.800 and standard deviation of 2.067
# - ***Act 2017 Science comes from a normal distribution***, based on a student t test with threshold of 0.050 and p value:0.064. It has a mean of 21.451, median of 21.300 and standard deviation of 1.739
# - Act 2017 Composite does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.038. The null hypothesis can be rejected. It has a mean of 21.520, median of 21.400 and standard deviation of 2.021
# - Sat 2018 Participation does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.000. The null hypothesis can be rejected. It has a mean of 0.457, median of 0.520 and standard deviation of 0.373
# - Sat 2018 Evidence Based Reading And Writing does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.018. The null hypothesis can be rejected. It has a mean of 563.686, median of 552.000 and standard deviation of 47.503
# - ***Sat 2018 Math comes from a normal distribution***, based on a student t test with threshold of 0.050 and p value:0.089. It has a mean of 556.235, median of 544.000 and standard deviation of 47.773
# - Sat 2018 Total does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.015. The null hypothesis can be rejected. It has a mean of 1120.020, median of 1098.000 and standard deviation of 94.155
# - Act 2018 Participation does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.000. The null hypothesis can be rejected. It has a mean of 0.616, median of 0.660 and standard deviation of 0.341
# - Act 2018 English does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.011. The null hypothesis can be rejected. It has a mean of 20.988, median of 20.200 and standard deviation of 2.446
# - Act 2018 Math does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.009. The null hypothesis can be rejected. It has a mean of 21.125, median of 20.700 and standard deviation of 2.036
# - Act 2018 Reading does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.009. The null hypothesis can be rejected. It has a mean of 22.016, median of 21.600 and standard deviation of 2.167
# - Act 2018 Science does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.011. The null hypothesis can be rejected. It has a mean of 21.345, median of 21.100 and standard deviation of 1.870
# - Act 2018 Composite does not come from a normal distribution, based on a student t test with threshold of 0.050 and p value:0.013. The null hypothesis can be rejected. It has a mean of 21.486, median of 21.300 and standard deviation of 2.106

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# ### Answer:
# - Participation rates for SAT and ACT generally does not follow a normal distribution.
#
# - Math scores does appear to slightly normally distributed, based on a normal t test with a threshold of 0.05. This would mean estimates of Math and reading scores will have a higher percentage of being close to its mean values.
#
# - There are not enough evidence to support the hypothesis that reading scores resemble a normal distribution. Estimates made for reading scores will not necessarily be close to the mean.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# As we are given only the mean participation rates for both SAT and ACT, it is not sufficient enough for us to conduct further inference into these data. SAT and ACT participations are two independent events that may or may not overlap (a student may choose to take both tests, although unlikely)
#
# It also does not make any sense to compare the distribution of SAT and ACT participation rates, because a high participation in one actually correlates to the lower participation in another, due to strong preferences over a single test.

# %%
def subplot_scatter(df, list_of_columns,figsize=(16,6),sharex=True,sharey=True, labels_append="",fit_reg=True):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=figsize,sharex=sharex, sharey=sharey) # You'll want to specify your figsize
    
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].set_title(list_of_columns[i][0].replace("_"," ").title() + " vs " + list_of_columns[i][1].replace("_"," ").title() + " " + labels_append )
        p = sns.regplot(data=df[list_of_columns[i]], x=list_of_columns[i][1],y=list_of_columns[i][0], ax=ax[i],fit_reg=fit_reg)
        p.set_xlabel(list_of_columns[i][1].replace("_"," ").title()+ " " + labels_append)
        p.set_ylabel(list_of_columns[i][0].replace("_"," ").title()+ " " + labels_append)
    
    if len(list_of_columns) < 2:
        fig.delaxes(ax[1])

# %%
cols = [['sat_2017_participation','act_2017_participation']]
subplot_scatter(final, cols, labels_append="Rate");

# %% [markdown]
# There appears to have a negative correlation between SAT 2017 and ACT 2017 participation rate.
# From the data, it seems to suggest that each state typically have a preference where the focus is taking either one of the test, and not both.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %%
cols = [['sat_2017_math','act_2017_math'],['sat_2018_math','act_2018_math']]
subplot_scatter(final, cols, labels_append="Scores",fit_reg=False);

# %% [markdown]
# Answer: No. There does not seem to be a strong linear relationship between SAT and ACT Math scores for both 2017 and 2018. Most students who took SAT may not be taking ACT and vice versa

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
cols = [['sat_2017_total','act_2017_composite'],['sat_2018_total','act_2018_composite']]
subplot_scatter(final, cols, labels_append="Scores",fit_reg=False);

# %% [markdown]
# Comparison between SAT and ACT total / composite scores shows that there are no strong correlations between these two variables. The possible inferences from this:
#
#     - Supports the finding above that participants that excelled in one test may not participate in another test
#     - The SAT and ACT test are significantly different from each other, participants that excelled in one test doesn't imply that they will perform well in the other.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
cols = [['sat_2017_participation','sat_2018_participation'],['act_2017_participation','act_2018_participation']]
subplot_scatter(final, cols, labels_append="Rate",fit_reg=True);

# %%
cols = [['sat_2017_participation','act_2017_participation'],['sat_2018_participation','act_2018_participation']]
subplot_scatter(final, cols, labels_append="Rate");

# %% [markdown]
# Interesting observations:
# - There are few states that have a very low participation rate for 2017 SAT and a very high participation rate for 2018
# - There are a few states that have close to 0 percent in SAT participation rates but close to 100 percent on ACT participation rate for 2017 and 2018
# - There are a few states with very low participation rate for SAT but they are have the highest scores among all other states

# %%
final[(final['sat_2017_participation'] < 0.2) & (final['sat_2018_participation'] > 0.8)][['state','sat_2017_participation','sat_2018_participation','sat_2017_total','sat_2018_total']]
# Out:
#        state  sat_2017_participation  sat_2018_participation  sat_2017_total  \
# 5   Colorado                    0.11                    1.00            1201
# 13  Illinois                    0.09                    0.99            1115
#
#     sat_2018_total
# 5             1025
# 13            1019

# %% [markdown]
# #### Colorado and Illinois has a big change in participation rates from 2017 to 2018
# - Colorado have a participation rate of 11% at 2017 and it increased to 100% at 2018
#
#     - This is due to the fact that the Colorado and college board had mandated all high school students to sit for mandatory SAT from 2018 onwards. Thus the participation increased to 100%. Ref: [Colodaro-SAT-Change](https://www.testive.com/colorado-sat-change-2017/)
#
# - Illinois had a participation rate of 9% at 2017 and increased to 99% at 2018
#     - Same as Colorado, the Illinois college board had mandated all high school students to sit for mandatory SAT from 2018 onwards. Ref: [Illinois](https://www.testive.com/illinois/), which contributed to the near perfect participation rate of 99%

# %%
top_act_states = final[(final['sat_2018_participation'] < 0.1 ) & (final['act_2018_participation'] > 0.9)][['state','sat_2018_participation','act_2018_participation','sat_2018_total','act_2018_composite']].sort_values(by=['act_2018_participation','act_2018_composite'],ascending=False).reset_index(drop=True)
top_act_states
# Out:
#            state  sat_2018_participation  act_2018_participation  \
# 0      Wisconsin                    0.03                    1.00
# 1           Utah                    0.04                    1.00
# 2       Kentucky                    0.04                    1.00
# 3       Nebraska                    0.03                    1.00
# 4       Missouri                    0.04                    1.00
# 5        Wyoming                    0.03                    1.00
# 6      Tennessee                    0.06                    1.00
# 7       Arkansas                    0.05                    1.00
# 8       Oklahoma                    0.08                    1.00
# 9      Louisiana                    0.04                    1.00
# 10       Alabama                    0.06                    1.00
# 11   Mississippi                    0.03                    1.00
# 12     Minnesota                    0.04                    0.99
# ...

# %%
top_sat_states = final[(final['sat_2018_participation'] < 0.1 )].sort_values(by=['sat_2018_total'],ascending=False)[['state','sat_2018_participation','sat_2018_total']]
top_sat_states.head(6)
# Out:
#            state  sat_2018_participation  sat_2018_total
# 23     Minnesota                    0.04            1298
# 49     Wisconsin                    0.03            1294
# 34  North Dakota                    0.02            1283
# 15          Iowa                    0.03            1265
# 16        Kansas                    0.04            1265
# 25      Missouri                    0.04            1262

# %%
plt.title('SAT 2018 Scores Distribution')
# plt.ylabel("Scores")
p = sns.boxplot(final['sat_2018_total'],orient='v');
p.set_ylabel("Scores");
p.set_xlabel("SAT 2018");

# %%
final['sat_2018_total'].describe()
# Out:
# count      51.000000
# mean     1120.019608
# std        94.155083
# min       977.000000
# 25%      1057.500000
# 50%      1098.000000
# 75%      1204.000000
# max      1298.000000
# Name: sat_2018_total, dtype: float64

# %%
final[final['sat_2018_total'] == 1298][['state','sat_2018_participation','sat_2018_total']]
# Out:
#         state  sat_2018_participation  sat_2018_total
# 23  Minnesota                    0.04            1298

# %%
final['act_2018_composite'].describe()
# Out:
# count    51.000000
# mean     21.486275
# std       2.106278
# min      17.700000
# 25%      19.950000
# 50%      21.300000
# 75%      23.550000
# max      25.600000
# Name: act_2018_composite, dtype: float64

# %%
final[final['state'] == 'Minnesota'][['state','sat_2018_participation','sat_2018_total','act_2018_participation','act_2018_composite']]
# Out:
#         state  sat_2018_participation  sat_2018_total  act_2018_participation  \
# 23  Minnesota                    0.04            1298                    0.99
#
#     act_2018_composite
# 23                21.3

# %% [markdown]
# ### Minnesota - Observation
# The state of Minnesota has the highest average score (1298) for SAT 2018 , despite a participation rate of only 4%. This suggest that most of the students from Minnesota that attempted SAT  signed up voluntarily and are highly prepared to excel on the test.
# As we can see from the [admission requirements for the University of Minnesota](https://admissions.tc.umn.edu/freshman/writing.html), test scores from either the ACT or SAT is accepted during the admission process. This shows that students who are really serious about entering University will attempt to increase their chances of admission by excelling in either or both of the test. As a contrast, Minnesta has a ACT participation rate of 99% in 2018, with a composite score of 21.3, which also happens to be the median of the scores distribution.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
avg_participation_2018.sort_values(by=['avg_participation'], ascending=True).head(5)
# Out:
#            state  sat_2018_participation  act_2018_participation  \
# 15          Iowa                    0.03                    0.68
# 16        Kansas                    0.04                    0.71
# 1         Alaska                    0.43                    0.33
# 41  South Dakota                    0.03                    0.77
# 31    New Mexico                    0.16                    0.67
#
#     avg_participation
# 15              0.355
# 16              0.375
# 1               0.380
# 41              0.400
# 31              0.415

# %% [markdown]
# ### States with lowest participation scores in both tests:
#     1. Iowa (Lowest)
#     2. Kansas
#     3. Alaska
#     4. South Dakota
#     5. New Mexico
#
# The 5 states above appears to have the lowest mean participation scores for both ACT and SAT in 2018.

# %% [markdown]
# ***
# **Ways to increase participation Rates**
#
# The most effective way to increase ACT / SAT participation would be to make the test mandatory for all high school students, which is done by Colorado and Illinois that have increased their participation rates from 11% and 9% to 100% and 99% respectively at 2018.
#
# The college board can vote to make SAT / ACT a mandatory for college admissions, which will significantly increase the participation on either tests. This is particularly true for Iowa, which has the lowest mean participation scores for both test. A quick survey on The University of Iowa [admission requirements](https://admissions.uiowa.edu/academics/first-year-admission) revealed that neither SAT nor ACT is mandatory for undergraduate admissions, which could be one of the main reasons why the participation rates are low.
#
# A less intrusive way would be to get colleges and universities to explicitly accept SAT scores during their admission process.
# Taking Minnesota as an example, the majority of students will take ACT over SAT as it is the norm over the years. A quick check online reveals that not all Minessota Universities explicitly accept SAT Scores, such as:
#
# - [Minnesota State University Mankato](https://mankato.mnsu.edu/future-students/admissions/undergraduate-admissions/admission-requirements/)
#
# Thus, colleges and universities admission requirements can heavily influence a state's participation on either of the tests.
